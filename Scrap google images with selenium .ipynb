# %%
! pip install selenium --q

# %%
import os
import time
import urllib
import pandas as pd
import urllib.request
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support import expected_conditions as EC

# %%
driver_path = "chromedriver.exe"
google_url='https://www.google.com'
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.default_content_setting_values.notifications" : 2}
chrome_options.add_experimental_option("prefs",prefs)
driver = webdriver.Chrome(driver_path)#, chrome_options=chrome_options)
driver.get(google_url)
driver.maximize_window()
time.sleep(5)

# %%
# search_bar = driver.find_element("xpath","//textarea[@class='gLFyf']")
# search_bar.send_keys('books images')
# search_bar.send_keys(Keys.ENTER)
# time.sleep(4)


img_src = []
site_url = driver.find_element("xpath","//div[@class='yuRUbf']//a").click()
time.sleep(5)
img = driver.find_elements("xpath","//div[@class='MorZF']/img")
for i,x in enumerate(img):
    src = x.get_attribute('src')
    print(src)
    img_src.append(src)
    urllib.request.urlretrieve(
        src, f"C:\\Users\\Administrator\\Desktop\\eshal\\google_pics\\captcha{i}.png")
img_data = pd.DataFrame(img_src)
img_data.to_csv('img_src.csv',index=False)
# Out:
# https://media.istockphoto.com/id/1460007248/photo/library-research-and-row-of-books-on-bookshelf-for-reading-knowledge-and-educational-learning.webp?b=1&s=170667a&w=0&k=20&c=TngiUK4f7spBY0U1r3xdicmFBK96Bi4JRrF4sNf2ELo=
# https://media.istockphoto.com/id/1354989842/photo/banner-with-books-business-and-education-background-back-to-school-concept.webp?b=1&s=170667a&w=0&k=20&c=sryJ6CANaeQ7vSw9TG_Z6dFb9wGlTdIHDh5_zxkIT5M=
# https://media.istockphoto.com/id/1421080285/photo/colored-books-on-light-background-education-school.webp?b=1&s=170667a&w=0&k=20&c=_azu_R-5-a26wGlrtusK_CWPuYXa9vtPg4nREZQpQu0=
# https://media.istockphoto.com/id/1411029939/photo/top-view-on-colorful-stacked-books-education-and-learning-concept-background.webp?b=1&s=170667a&w=0&k=20&c=uw6avsgigpECDP-THvvqSLAs2M93HRvIOYCNhnOe70s=
# ...

# %%
img_data
# Out:
#                                                     0
# 0   https://media.istockphoto.com/id/1460007248/ph...
# 1   https://media.istockphoto.com/id/1354989842/ph...
# 2   https://media.istockphoto.com/id/1421080285/ph...
# 3   https://media.istockphoto.com/id/1411029939/ph...
# 4   https://media.istockphoto.com/id/1398466630/ph...
# 5   https://media.istockphoto.com/id/1453081662/ph...
# 6   https://media.istockphoto.com/id/1456438531/ph...
# 7   https://media.istockphoto.com/id/1413840933/ph...
# 8   https://media.istockphoto.com/id/1383889737/ph...
# 9   https://media.istockphoto.com/id/1373105718/ph...
# 10  https://media.istockphoto.com/id/1401178460/ph...
# 11  https://media.istockphoto.com/id/1402835350/ph...
# 12  https://media.istockphoto.com/id/1457739733/ph...
# 13  https://media.istockphoto.com/id/1434386918/ph...
# 14  https://media.istockphoto.com/id/1402880637/ph...
# 15  https://media.istockphoto.com/id/1306307586/ph...
# ...
